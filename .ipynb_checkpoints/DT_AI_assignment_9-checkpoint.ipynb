# %%
import numpy as np
import pandas as pd
import scikitplot as skplt
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import graphviz

# %%
data = {
        "Furniture":[0,1,0,0,1],
        "room_numbers":[3,3,4,3,4],
        "new_kitchen":[1,0,0,0,0],
        "acceptable":[1,0,1,0,1]
        }
df = pd.DataFrame(data=data)
df["acceptable"]
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: acceptable, dtype: int64

# %%
X_train = df.drop("acceptable",axis=1)
y_train = df["acceptable"]

# %%
X_train.columns
# Out:
# Index(['Furniture', 'room_numbers', 'new_kitchen'], dtype='object')

# %%
treeModel = DecisionTreeClassifier(criterion="entropy")
treeModel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn import tree
tree.plot_tree(clf.fit(X_train,y_train))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-60ca526ff9e0> in <module>
#       1 from sklearn import tree
# ----> 2 tree.plot_tree(clf.fit(X_train,y_train))
#
# AttributeError: module 'sklearn.tree' has no attribute 'plot_tree'

# %%
dot_data = tree.export_graphviz(treeModel, out_file=None,
                                class_names=["no","yes"],
                                feature_names=X_train.columns,
                                filled=True, rounded=True,  
                                special_characters=False)  
graph = graphviz.Source(dot_data)  
graph

# %%
treeModel.decision_path
# Out:
# <bound method BaseDecisionTree.decision_path of DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='log2', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')>

# %%
y_train.name
# Out:
# 'acceptable'
